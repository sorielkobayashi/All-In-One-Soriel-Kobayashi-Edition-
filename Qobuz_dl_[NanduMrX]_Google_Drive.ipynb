# %% [markdown]
# ![qobuz_logo_og.png](data:image/png;base64,...)

# %% [markdown]
# #<img src='https://i.ibb.co/nD9NnTc/drive.png' height="50" alt="GDrive"/>

# %%
#@markdown <h2>←Mount Google Drive.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
 #@markdown <h2>←Upgrade Qobuz-dl.
# !pip3 install --upgrade qobuz-dl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 KB 10.7 MB/s eta 0:00:00
# ...

# %%
#@markdown <h2>←Qobuz-dl Configuration.
# !qobuz-dl
# Out:
# Creating config file: /root/.config/qobuz-dl/config.ini
# Enter your email:
# - rubch07@gmail.com
# Enter your password
# - Mexico_2022
# Folder for downloads (leave empty for default 'Qobuz Downloads')
# - /content/drive/MyDrive/QOBUZ-DL
# Download quality (5, 6, 7, 27) [320, LOSSLESS, 24B <96KHZ, 24B >96KHZ]
# (leave empty for default '6')
# - 27
# Getting tokens. Please wait...
# Config file updated. Edit more options in /root/.config/qobuz-dl/config.ini
# so you don't have to call custom flags every time you run a qobuz-dl command.
# usage: qobuz-dl
#        [-h]
#        [-r]
#        [-p]
#        {fun,dl,lucky}
#        ...
#
# The ultimate Qobuz music downloader.
# See usage examples on https://github.com/vitiko98/qobuz-dl
#
# optional arguments:
#   -h, --help
#     show this help message and exit
#   -r, --reset
#     create/reset config file
#   -p, --purge
#     purge/delete downloaded-IDs database
#
# commands:
#   run qobuz-dl <command> --help for more info
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ***SELECT THE NO. FOR DOWNLOAD QUALITY.***
#
#
# *5    - MP3-320 kbps.*
#
# *6    - CD-16Bit/44,KKHz.*
#
# *7    - Hi-Res-24-bit/up to 96KHz.*
#
# *27   - Hi-Res-24-bit/up to 192KHz.*

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://play.qobuz.com/artist/9829302" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://www.qobuz.com/de-de/album/window-bustin-bass-bassotronics/tocxapk468sdb" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art
# Out:
# Logging...
# Logged: OK
# Membership: Hi-Fi Sublime+
# Set max quality: 27 - 24 bit, >96kHz
#
#
# Downloading: Window Bustin' Bass
# Quality: FLAC (24/48)
#
# cover.jpg: 100% 72.9k/72.9k [00:00<00:00, 193kiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Bassotronics - Window Bustin' Bass (2022) [24B-48kHz]/.00.tmp: 100% 18.7M/18.7M [00:01<00:00, 10.6MiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Bassotronics - Window Bustin' Bass (2022) [24B-48kHz]/.01.tmp: 100% 33.3M/33.3M [00:02<00:00, 11.7MiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Bassotronics - Window Bustin' Bass (2022) [24B-48kHz]/.02.tmp: 100% 40.2M/40.2M [00:03<00:00, 11.4MiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Bassotronics - Window Bustin' Bass (2022) [24B-48kHz]/.03.tmp: 100% 32.9M/32.9M [00:04<00:00, 7.64MiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Bassotronics - Window Bustin' Bass (2022) [24B-48kHz]/.04.tmp: 100% 40.0M/40.0M [00:03<00:00, 11.1MiB/s]
# ...

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://www.qobuz.com/de-de/album/wicked-waifu-shiki-tmns/edu72y7jslhla" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art
# Out:
# Logging...
# Logged: OK
# Membership: Hi-Fi Sublime+
# Set max quality: 27 - 24 bit, >96kHz
#
#
# Downloading: Wicked Waifu
# Quality: FLAC (24/44.1)
#
# cover.jpg: 100% 87.3k/87.3k [00:00<00:00, 464kiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Shiki-TMNS - Wicked Waifu (2022) [24B-44.1kHz]/.00.tmp: 100% 23.5M/23.5M [00:04<00:00, 6.14MiB/s]
# Completed

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://www.qobuz.com/de-de/album/booty-shiki-tmns-amp-kodama-boy/va30zzafacpuc" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art
# Out:
# Logging...
# Logged: OK
# Membership: Hi-Fi Sublime+
# Set max quality: 27 - 24 bit, >96kHz
#
#
# Downloading: Booty
# Quality: FLAC (24/44.1)
#
# cover.jpg: 100% 49.5k/49.5k [00:00<00:00, 131kiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Shiki-TMNS - Booty (2022) [24B-44.1kHz]/.00.tmp: 100% 23.5M/23.5M [00:02<00:00, 12.2MiB/s]
# Completed

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://www.qobuz.com/de-de/album/enjoy-the-night-shiki-tmns/ahen83simzxac" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art
# Out:
# Logging...
# Logged: OK
# Membership: Hi-Fi Sublime+
# Set max quality: 27 - 24 bit, >96kHz
#
#
# Downloading: Enjoy The Night
# Quality: FLAC (24/44.1)
#
# cover.jpg: 100% 64.6k/64.6k [00:00<00:00, 170kiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Shiki-TMNS - Enjoy The Night (2022) [24B-44.1kHz]/.00.tmp: 100% 35.1M/35.1M [00:03<00:00, 10.6MiB/s]
# Completed

# %%
#@markdown <h3> Download Qobuz Musics.
LINK = "https://www.qobuz.com/de-de/album/protag-mindset-shiki-tmns-amp-malcolm-lashad/dmzewjk54s7ia" #@param {type:"string"}
QUALITY = "27" #@param {type:"string"}
# !qobuz-dl dl $LINK -q $QUALITY --embed-art
# Out:
# Logging...
# Logged: OK
# Membership: Hi-Fi Sublime+
# Set max quality: 27 - 24 bit, >96kHz
#
#
# Downloading: Protag Mindset
# Quality: FLAC (24/44.1)
#
# cover.jpg: 100% 90.7k/90.7k [00:00<00:00, 5.59MiB/s]
# /content/drive/MyDrive/QOBUZ-DL/Shiki-TMNS - Protag Mindset (2022) [24B-44.1kHz]/.00.tmp: 100% 28.5M/28.5M [00:02<00:00, 12.1MiB/s]
# Completed
